# %%
from kcatbench import DLKcatWrapper, BaseModel


wrap = DLKcatWrapper()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1059/3841987680.py in <module>
# ----> 1 from kcatbench import DLKcatWrapper, BaseModel
#       2
#       3
#       4 wrap = DLKcatWrapper()
#       5
#
# ~/Documents/Projects/kcat-prediction-benchmarking/src/kcatbench/__init__.py in <module>
# ----> 1 from .model_wrapper.dlkcat_wrapper import DLKcatWrapper
#       2 from .model_wrapper.base import BaseModel
#       3
#       4 __all__ = [
#       5     'DLKcatWrapper',
#
# ~/Documents/Projects/kcat-prediction-benchmarking/src/kcatbench/model_wrapper/dlkcat_wrapper.py in <module>
#      11
#      12 from .base import BaseModel
# ---> 13 from prediction_for_input import split_sequence
#      14 import pandas as pd
#      15 import zipfile
#
# ...
